# %%
from script.core.utils import scrab_data, get_table, results_summarization

# %%
path = './results/logs/2018-3-25.txt'

# %%
info = scrab_data(path)

# %%
info.keys()
# Out:
# dict_keys(['cnn', 'Linear Regression', 'LinearSVC', 'RandomForestClassifier', 'LGBMClassifier'])

# %%
table, [name_best_model, best_model] = get_table(info)

# %%
table
# Out:
#                         Accuracy  F1 macro  F1 weighted
# Models
# LGBMClassifier          0.641553  0.512065     0.630832
# Linear Regression       0.602740  0.371103     0.559509
# LinearSVC               0.684932  0.532844     0.668673
# RandomForestClassifier  0.599089  0.410288     0.575240
# cnn                     0.084282  0.020052     0.023295

# %%
name_best_model
# Out:
# 'LinearSVC'

# %%
results_summarization('2018-3-25')
